# %%
# Dependencies
import matplotlib.pyplot as plt
# %matplotlib inline

import os
import numpy as np
import tensorflow as tf

os.environ['KMP_DUPLICATE_LIB_OK']='True'

from tensorflow import keras
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg19 import (
    VGG19, 
    preprocess_input, 
    decode_predictions
)

# %%
# Load the VGG19 model
# https://keras.io/api/applications/vgg/#vgg19-function
model = VGG19(include_top=True, weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels.h5
# 574710816/574710816 [==============================] - 12s 0us/step

# %%
# Define default image size for VGG19
image_size = (224, 224)

# %%
# Load the image and resize to default image size
from urllib.request import urlopen
from io import BytesIO
image_path = "https://static.bc-edx.com/data/dl-1-2/m23/lessons/2/img/bird1.jpg"
with urlopen(image_path) as raw:
    img = image.load_img(BytesIO(raw.read()), target_size=image_size)
img
plt.imshow(img)

# %%
# Preprocess image for model prediction
# This step handles scaling and normalization for VGG19
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
# Make predictions
# Out:
# 1/1 [==============================] - 1s 1s/step
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 35363/35363 [==============================] - 0s 0us/step
# Predicted: [[('n02007558', 'flamingo', 0.9688597), ('n01855672', 'goose', 0.0099396035), ('n02006656', 'spoonbill', 0.008081734)]]

# %%
# Refactor above steps into reusable function

# %%
image_path = "https://static.bc-edx.com/data/dl-1-2/m23/lessons/2/img/bird2.jpg"
# Use function to predict image
# Out:
# 1/1 [==============================] - 1s 757ms/step
# Predicted: [[('n01622779', 'great_grey_owl', 0.9347006), ('n01608432', 'kite', 0.008001432), ('n02018795', 'bustard', 0.006982974)]]
